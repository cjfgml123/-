# %% [markdown]
# # 새 섹션

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import sys
import numpy as np 
import scipy as sp 
from sklearn import datasets , tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

print('sys version: ', sys.version)
print('numpy version: ', np.__version__)
print('scipy version: ', sp.__version__)

# %%
def main () :
    dataset = datasets.load_iris ()

    features = dataset.data
    targets = dataset.target

    petal_features = features [:,2:]

    ciris = DecisionTreeClassifier(criterion= 'entropy', max_depth=3 )
    ciris.fit(petal_features, targets)

    with open('/content/drive/My Drive/실무가보이는머신러닝_딥러닝/chapter03/iris-dtree.dot', mode = 'w') as f :
        tree.export_graphviz(ciris, out_file= f)

if __name__ == '__main__' :
    main()

# %%
cancer = datasets.load_breast_cancer()

x_train, x_test, y_train, y_test = train_test_split(cancer.data,
                                                    cancer.target,
                                                    stratify=cancer.target,
                                                    test_size=0.2,
                                                    random_state=42)

# %%
#y_train = y_train.astype('int')
#y_train.dtype

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)

print(x_train.dtype)
print(y_train.dtype)
print(x_test.dtype)
print(y_test.dtype)

# %%
cancer_model = DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
cancer_model.fit(x_train,y_train)
print("훈련점수: {:.3f} ".format(cancer_model.score(x_train, y_train)))
print("테스트점수: {:.3f} ".format(cancer_model.score(x_test, y_test)))

# %%
with open('/content/drive/My Drive/실무가보이는머신러닝_딥러닝/chapter03/cancer-dtree.dot', mode = 'w') as f :
        tree.export_graphviz(cancer_model, out_file= f,
                             feature_names= cancer.feature_names,
                             class_names=['cancer','not cancer'])

# %%
import graphviz
from IPython.display import display
with open('/content/drive/My Drive/실무가보이는머신러닝_딥러닝/chapter03/cancer-dtree.dot') as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))
